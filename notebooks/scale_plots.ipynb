# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/jpinkney/code/clip2latent/all_scores_2022-06-10 05:54:12.753816.csv')

# %%
for s in (1, 100, 250):
    this_df = df[df["skips"] == s][[" cond_scale", " score"]]
    plt.plot(this_df[" cond_scale"], this_df[" score"], '-o', label=s)
plt.grid()
plt.legend()
plt.xscale('log')
plt.show()
